# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/vaishnavi/Desktop/DBDA/ML Practical/Day_2/HousingData.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
#replacing null values
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 394 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     394 non-null    float64
#  1   ZN       394 non-null    float64
#  2   INDUS    394 non-null    float64
#  3   CHAS     394 non-null    float64
#  4   NOX      394 non-null    float64
#  5   RM       394 non-null    float64
#  6   AGE      394 non-null    float64
#  7   DIS      394 non-null    float64
#  8   RAD      394 non-null    int64
#  9   TAX      394 non-null    int64
#  10  PTRATIO  394 non-null    float64
#  11  B        394 non-null    float64
#  12  LSTAT    394 non-null    float64
#  13  MEDV     394 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 46.2 KB

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.188075  0.391552 -0.051970  0.416160 -0.227170  0.341311
# ZN      -0.188075  1.000000 -0.521256 -0.033357 -0.515660  0.343210 -0.568174
# INDUS    0.391552 -0.521256  1.000000  0.049820  0.762737 -0.403068  0.642387
# CHAS    -0.051970 -0.033357  0.049820  1.000000  0.076661  0.095308  0.072644
# NOX      0.416160 -0.515660  0.762737  0.076661  1.000000 -0.316563  0.732540
# RM      -0.227170  0.343210 -0.403068  0.095308 -0.316563  1.000000 -0.248670
# AGE      0.341311 -0.568174  0.642387  0.072644  0.732540 -0.248670  1.000000
# DIS     -0.365052  0.645359 -0.696569 -0.095037 -0.768137  0.218713 -0.753547
# RAD      0.608667 -0.298773  0.591944  0.014102  0.628170 -0.236057  0.443585
# TAX      0.560841 -0.305768  0.734204 -0.026513  0.679824 -0.320561  0.504472
# PTRATIO  0.265428 -0.422164  0.395691 -0.104995  0.210216 -0.390686  0.264968
# ...

# %%
plt.scatter(df['CRIM'],df['MEDV'])

# %%
plt.scatter(df['ZN'],df['MEDV'])

# %%
plt.scatter(df['INDUS'],df['MEDV'])

# %%
plt.scatter(df['CHAS'],df['MEDV'])

# %%
plt.scatter(df['NOX'],df['MEDV'])

# %%
plt.scatter(df['RM'],df['MEDV'])

# %%
plt.scatter(df['NOX'],df['MEDV'])

# %%
plt.scatter(df['AGE'],df['MEDV'])

# %%
plt.scatter(df['DIS'],df['MEDV'])

# %%
plt.scatter(df['RAD'],df['MEDV'])

# %%
plt.scatter(df['TAX'],df['MEDV'])

# %%
plt.scatter(df['PTRATIO'],df['MEDV'])

# %%
plt.scatter(df['B'],df['MEDV'])

# %%
plt.scatter(df['LSTAT'],df['MEDV'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 394 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     394 non-null    float64
#  1   ZN       394 non-null    float64
#  2   INDUS    394 non-null    float64
#  3   CHAS     394 non-null    float64
#  4   NOX      394 non-null    float64
#  5   RM       394 non-null    float64
#  6   AGE      394 non-null    float64
#  7   DIS      394 non-null    float64
#  8   RAD      394 non-null    int64
#  9   TAX      394 non-null    int64
#  10  PTRATIO  394 non-null    float64
#  11  B        394 non-null    float64
#  12  LSTAT    394 non-null    float64
#  13  MEDV     394 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 46.2 KB

# %%
#check if outliers
plt.figure(figsize=(2,1))
plt.boxplot(df['CRIM'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d421f940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d421fe80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d421f6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d41d53f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d41d4880>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['ZN'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d401eef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d401f430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d401ec50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d401f970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d401fc10>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['INDUS'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d4073d60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d40a0220>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d4073ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d40a0760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d40a0a00>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['CHAS'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d40cfcd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d520c250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d40cfa30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d520c790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d520ca30>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['NOX'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d52608b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d5260df0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d5260610>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d5261330>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d52615d0>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['RM'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d52bcd60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d52bd2a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d52bcac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d52bd7e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d52bda80>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['DIS'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d5315870>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d5315db0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d53155d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d53162f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d5316590>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['RAD'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d5369c30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d536a170>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d5369990>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d536a6b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d536a950>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['TAX'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d53ca3e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d53ca920>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d53ca140>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d53cae60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d53cb100>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['PTRATIO'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d5422ef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d5423430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d5422ce0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d5423970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d5423c10>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['B'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d1a009a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d19ca2f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d3d45f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d19cbf70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d1827490>],
#  'means': []}

# %%
plt.figure(figsize=(2,1))
plt.boxplot(df['LSTAT'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b6d3ecca00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b6d3ecdfc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b6d3eae8f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b6d1c45ab0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b6d1c46500>],
#  'means': []}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 394 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     394 non-null    float64
#  1   ZN       394 non-null    float64
#  2   INDUS    394 non-null    float64
#  3   CHAS     394 non-null    float64
#  4   NOX      394 non-null    float64
#  5   RM       394 non-null    float64
#  6   AGE      394 non-null    float64
#  7   DIS      394 non-null    float64
#  8   RAD      394 non-null    int64
#  9   TAX      394 non-null    int64
#  10  PTRATIO  394 non-null    float64
#  11  B        394 non-null    float64
#  12  LSTAT    394 non-null    float64
#  13  MEDV     394 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 46.2 KB

# %%
X = df.iloc[:,[2,4,7,8,9,10,12]].values
print(X.shape)
# Out:
# (394, 7)

# %%
y = df.iloc[:,13].values
print(y.shape)
# Out:
# (394,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,
                                                 y,
                                                 test_size = 0.2,
                                                 random_state = 123)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (315, 7) (79, 7) (315,) (79,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
yhat = model.predict(X_test)
yhat.shape
# Out:
# (79,)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,yhat)
# Out:
# 0.7407050244445534

# %%
#r2_score/accuracy  is 74%
